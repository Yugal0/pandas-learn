# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,2,3,np.nan,9,8])
dates=pd.date_range("20240501",periods=10)
dates

df=pd.DataFrame(np.random.randn(10,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-05-01  0.966660  0.343286 -0.456215  0.512733
# 2024-05-02 -0.077229  1.164225 -1.353119  1.495300
# 2024-05-03  1.633625 -0.279848 -2.713652 -1.494575
# 2024-05-04  0.252859  0.635852 -0.316510 -0.092863
# 2024-05-05  1.544462 -1.010753  0.776725 -0.879106
# 2024-05-06 -1.145845 -0.911478 -0.016490  1.549710
# 2024-05-07  0.035233  0.528649  0.152802 -0.064962
# 2024-05-08 -0.645410 -0.652854  0.380231  0.252525
# 2024-05-09 -0.325108  0.675415  0.407921 -0.757322
# 2024-05-10 -0.616604 -0.669579  1.375972  0.600873

# %%
df2=pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20240501"),
        "C": pd.Series(1,index=list(range(4)),dtype="float32"),
        "D": np.array([3]*4,dtype="int32"),
        "E": pd.Categorical(["test","train","test","train"]),
        "F":"foo",
    }
)
# print(df2)
df2.dtypes
df2.head(3)
# df2.tail()
df2.index
df2.columns
df2.to_numpy()
aa=df.to_numpy()
df.describe()
df.sort_index(axis=1,ascending=False)
df.sort_values(by="D")
# Out:
#                    A         B         C         D
# 2024-05-03  1.633625 -0.279848 -2.713652 -1.494575
# 2024-05-05  1.544462 -1.010753  0.776725 -0.879106
# 2024-05-09 -0.325108  0.675415  0.407921 -0.757322
# 2024-05-04  0.252859  0.635852 -0.316510 -0.092863
# 2024-05-07  0.035233  0.528649  0.152802 -0.064962
# 2024-05-08 -0.645410 -0.652854  0.380231  0.252525
# 2024-05-01  0.966660  0.343286 -0.456215  0.512733
# 2024-05-10 -0.616604 -0.669579  1.375972  0.600873
# 2024-05-02 -0.077229  1.164225 -1.353119  1.495300
# 2024-05-06 -1.145845 -0.911478 -0.016490  1.549710

# %%
# df[0:3]
# df.loc[dates[0]]
df.loc[dates[0],"A"]
df[df["A"]>0]
df3=df.copy()
df["E"]=["ss","sh"]*5
# df[df["A"].isin([0.354107,0.767608])]
df
# s1=pd.Series([1,2,3,4,5,6],index=pd.date_range("20250501",periods=6))
# s1
import os
df_bks=pd.read_excel(os.listdir(".")[1])
df_bks=df_bks.dropna(subset=["Name ","Datum"])
df_bks
# df_bks.drop([0,1],axis=0)

str1="RM_stacked"
for nm in df_bks["Name "]:
    if(not(str1 in nm)):
        df_bks=df_bks.drop("")


# df_bks_filter = df_bks[df_bks['Name '].str.contains('RM_stacked')]

# str1="jjjsdfldslf"
# str2="dfld"
# a= str2 in str1
# a

# df_bks
# df_bks.columns
# Out:
#                                 Name        Datum              Project  \
# 0                             RM_S3_1  19082018.0  Stacking electrodes
# 2                             RM_S3_2  19082018.0  Stacking electrodes
# 4                            RM_S12_1  19082018.0  Stacking electrodes
# 6                            RM_S12_2  19082018.0  Stacking electrodes
# 8                             RM_D3_1  19082018.0  Stacking electrodes
# 10                            RM_D3_2  19082018.0  Stacking electrodes
# 12                           RM_D12_1  19082018.0  Stacking electrodes
# 14                           RM_D12_2  19082018.0  Stacking electrodes
# 16                       RM_DS_3+12_1  19082018.0  Stacking electrodes
# 18                       RM_DS_3+12_2  19082018.0  Stacking electrodes
# 20                       RM_DS_12+3_1  19082018.0  Stacking electrodes
# 22                       RM_DS_12+3_2  19082018.0  Stacking electrodes
# 24       RM_stacked cells second S3_1  20180903.0  Stacking electrodes
# 26       RM_stacked cells second S3_2  20180903.0  Stacking electrodes
# 28      RM_stacked cells second S12_1  20180903.0  Stacking electrodes
# 30      RM_stacked cells second S12_2  20180903.0  Stacking electrodes
# 32       RM_stacked cells second D3_1  20180903.0  Stacking electrodes
# 34       RM_stacked cells second D3_2  20180903.0  Stacking electrodes
# 36      RM_stacked cells second D12_1  20180903.0  Stacking electrodes
# 38      RM_stacked cells second D12_2  20180903.0  Stacking electrodes
# 40  RM_stacked cells second DS_3+12_1  20180903.0  Stacking electrodes
# 42  RM_stacked cells second DS_3+12_2  20180903.0  Stacking electrodes
# 44  RM_stacked cells second DS_12+3_1  20180903.0  Stacking electrodes
# 46  RM_stacked cells second DS_12+3_2  20180903.0  Stacking electrodes
#
#     m_electrode [mg]  m_cc [mg]  M_coating [mg]  Porosity  \
# 0             25.105        0.0          25.105  0.530000
# 2             31.580        0.0          31.580  0.520000
# 4              6.720        0.0           6.720  0.560000
# 6              6.750        0.0           6.750  0.570000
# 8             65.625        0.0          65.625  0.515000
# 10            68.830        0.0          68.830  0.515000
# 12            13.630        0.0          13.630  0.570000
# 14            13.820        0.0          13.820  0.570000
# 16            33.585        0.0          33.585  0.536385
# 18            33.840        0.0          33.840  0.526977
# 20            35.455        0.0          35.455  0.530912
# 22            36.015        0.0          36.015  0.528791
# 24            26.480        0.0          26.480  0.530000
# 26            27.060        0.0          27.060  0.520000
# 28             6.410        0.0           6.410  0.410000
# 30             6.495        0.0           6.495  0.430000
# 32            58.700        0.0          58.700  0.520000
# 34            59.840        0.0          59.840  0.520000
# 36            13.165        0.0          13.165  0.410000
# 38            13.480        0.0          13.480  0.430000
# 40            34.480        0.0          34.480  0.489453
# 42            34.785        0.0          34.785  0.493533
# 44            35.035        0.0          35.035  0.503333
# 46            35.625        0.0          35.625  0.490702
#
#     Elyte conduct. [mS/cm]  Diameter [cm]  electr. thickn. [µm]  \
# 0                    0.353          1.095                 251.0
# 2                    0.353          1.095                 309.0
# 4                    0.353          1.095                  74.0
# 6                    0.353          1.095                  76.0
# 8                    0.353          1.095                 642.0
# 10                   0.353          1.095                 673.0
# 12                   0.353          1.095                 154.0
# 14                   0.353          1.095                 156.0
# 16                   0.353          1.095                 343.0
# 18                   0.353          1.095                 344.0
# 20                   0.353          1.095                 362.0
# 22                   0.353          1.095                 364.0
# 24                   0.353          1.095                 268.0
# 26                   0.353          1.095                 269.0
# 28                   0.353          1.095                  52.0
# 30                   0.353          1.095                  54.0
# 32                   0.353          1.095                 580.0
# 34                   0.353          1.095                 593.5
# 36                   0.353          1.095                 106.0
# 38                   0.353          1.095                 112.0
# 40                   0.353          1.095                 329.0
# 42                   0.353          1.095                 334.0
# 44                   0.353          1.095                 342.0
# 46                   0.353          1.095                 342.0
#
#     cc thickness [µm]  coating thickness [µm]  2* Rion [Ohm] (aus EC-Lab)  \
# 0                 0.0                   251.0                      1062.0
# 2                 0.0                   309.0                      1405.0
# 4                 0.0                    74.0                       473.0
# 6                 0.0                    76.0                       482.0
# 8                 0.0                   642.0                      2820.0
# 10                0.0                   673.0                      3164.0
# 12                0.0                   154.0                      1059.0
# 14                0.0                   156.0                      1031.0
# 16                0.0                   343.0                      2175.0
# 18                0.0                   344.0                      2316.0
# 20                0.0                   362.0                      1495.0
# 22                0.0                   364.0                      1631.0
# 24                0.0                   268.0                       986.0
# 26                0.0                   269.0                      1014.0
# 28                0.0                    52.0                       417.0
# 30                0.0                    54.0                       402.0
# 32                0.0                   580.0                      2217.0
# 34                0.0                   593.5                      2133.0
# 36                0.0                   106.0                       912.0
# 38                0.0                   112.0                       972.0
# 40                0.0                   329.0                      1968.0
# 42                0.0                   334.0                      1923.0
# 44                0.0                   342.0                         NaN
# 46                0.0                   342.0                         NaN
#
#          tau   McMullin   Comment  Masse Ref coating  Abtrag [%]
# 0   3.727258   7.032563       NaN                NaN         NaN
# 2   3.929923   7.557544       NaN                NaN         NaN
# 4   5.949497  10.624102       NaN                NaN         NaN
# 6   6.008570  10.541351       NaN                NaN         NaN
# 8   3.759968   7.300909       NaN                NaN         NaN
# 10  4.024310   7.814195       NaN                NaN         NaN
# 12  6.514978  11.429785       NaN                NaN         NaN
# 14  6.261404  10.984920       NaN                NaN         NaN
# 16  5.653332  10.539693       NaN                NaN         NaN
# 18  5.897044  11.190331       NaN                NaN         NaN
# 20  3.644330   6.864287       NaN                NaN         NaN
# 22  3.938217   7.447584       NaN                NaN         NaN
# 24  3.241013   6.115120  3.249510           6.190258         NaN
# 26  3.258006   6.265396       NaN                NaN         NaN
# 28  5.464864  13.328938  5.392750          12.851255         NaN
# 30  5.320636  12.373573       NaN                NaN         NaN
# 32  3.303725   6.353317  3.204987           6.163437         NaN
# 34  3.106249   5.973556       NaN                NaN         NaN
# 36  5.863213  14.300519  6.032947          14.362681         NaN
# 38  6.202682  14.424842       NaN                NaN         NaN
# 40  4.866345   9.942418  4.794639           9.756030         NaN
# 42  4.722933   9.569641       NaN                NaN         NaN
# 44       NaN        NaN       NaN                NaN         NaN
# 46       NaN        NaN       NaN                NaN         NaN

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,2,3,np.nan,9,8])
dates=pd.date_range("20240501",periods=10)
dates

df=pd.DataFrame(np.random.randn(10,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-05-01  0.966660  0.343286 -0.456215  0.512733
# 2024-05-02 -0.077229  1.164225 -1.353119  1.495300
# 2024-05-03  1.633625 -0.279848 -2.713652 -1.494575
# 2024-05-04  0.252859  0.635852 -0.316510 -0.092863
# 2024-05-05  1.544462 -1.010753  0.776725 -0.879106
# 2024-05-06 -1.145845 -0.911478 -0.016490  1.549710
# 2024-05-07  0.035233  0.528649  0.152802 -0.064962
# 2024-05-08 -0.645410 -0.652854  0.380231  0.252525
# 2024-05-09 -0.325108  0.675415  0.407921 -0.757322
# 2024-05-10 -0.616604 -0.669579  1.375972  0.600873

# %%
df2=pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20240501"),
        "C": pd.Series(1,index=list(range(4)),dtype="float32"),
        "D": np.array([3]*4,dtype="int32"),
        "E": pd.Categorical(["test","train","test","train"]),
        "F":"foo",
    }
)
# print(df2)
df2.dtypes
df2.head(3)
# df2.tail()
df2.index
df2.columns
df2.to_numpy()
aa=df.to_numpy()
df.describe()
df.sort_index(axis=1,ascending=False)
df.sort_values(by="D")
# Out:
#                    A         B         C         D
# 2024-05-03  1.633625 -0.279848 -2.713652 -1.494575
# 2024-05-05  1.544462 -1.010753  0.776725 -0.879106
# 2024-05-09 -0.325108  0.675415  0.407921 -0.757322
# 2024-05-04  0.252859  0.635852 -0.316510 -0.092863
# 2024-05-07  0.035233  0.528649  0.152802 -0.064962
# 2024-05-08 -0.645410 -0.652854  0.380231  0.252525
# 2024-05-01  0.966660  0.343286 -0.456215  0.512733
# 2024-05-10 -0.616604 -0.669579  1.375972  0.600873
# 2024-05-02 -0.077229  1.164225 -1.353119  1.495300
# 2024-05-06 -1.145845 -0.911478 -0.016490  1.549710

# %%
# df[0:3]
# df.loc[dates[0]]
df.loc[dates[0],"A"]
df[df["A"]>0]
df3=df.copy()
df["E"]=["ss","sh"]*5
# df[df["A"].isin([0.354107,0.767608])]
df
# s1=pd.Series([1,2,3,4,5,6],index=pd.date_range("20250501",periods=6))
# s1
import os
df_bks=pd.read_excel(os.listdir(".")[1])
df_bks=df_bks.dropna(subset=["Name ","Datum"])
df_bks
# df_bks.drop([0,1],axis=0)

str1="RM_stacked"
for nm in df_bks["Name "]:
    if(not(str1 in nm)):
        df_bks=df_bks.drop(df_bks["Name "])


# df_bks_filter = df_bks[df_bks['Name '].str.contains('RM_stacked')]

# str1="jjjsdfldslf"
# str2="dfld"
# a= str2 in str1
# a

# df_bks
# df_bks.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 20
#      18 for nm in df_bks["Name "]:
#      19     if(not(str1 in nm)):
# ---> 20         df_bks=df_bks.drop(df_bks["Name "])
#      23 # df_bks_filter = df_bks[df_bks['Name '].str.contains('RM_stacked')]
#      24
#      25 # str1="jjjsdfldslf"
#    (...)
#      30 # df_bks
#      31 # df_bks.columns
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
#    5257     errors: IgnoreRaise = "raise",
#    5258 ) -> DataFrame | None:
#    5259     """
#    5260     Drop specified labels from rows or columns.
#    5261
#    (...)
#    5394             weight  1.0     0.8
#    5395     """
# -> 5396     return super().drop(
#    5397         labels=labels,
#    5398         axis=axis,
#    5399         index=index,
#    5400         columns=columns,
#    5401         level=level,
#    5402         inplace=inplace,
#    5403         errors=errors,
#    5404     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:6977, in Index.drop(self, labels, errors)
#    6975 if mask.any():
#    6976     if errors != "ignore":
# -> 6977         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6978     indexer = indexer[~mask]
#    6979 return self.delete(indexer)
#
# KeyError: "['RM_S3_1', 'RM_S3_2', 'RM_S12_1', 'RM_S12_2', 'RM_D3_1', 'RM_D3_2', 'RM_D12_1', 'RM_D12_2', 'RM_DS_3+12_1', 'RM_DS_3+12_2', 'RM_DS_12+3_1', 'RM_DS_12+3_2', 'RM_stacked cells second S3_1', 'RM_stacked cells second S3_2', 'RM_stacked cells second S12_1', 'RM_stacked cells second S12_2', 'RM_stacked cells second D3_1', 'RM_stacked cells second D3_2', 'RM_stacked cells second D12_1', 'RM_stacked cells second D12_2', 'RM_stacked cells second DS_3+12_1', 'RM_stacked cells second DS_3+12_2', 'RM_stacked cells second DS_12+3_1', 'RM_stacked cells second DS_12+3_2'] not found in axis"

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,2,3,np.nan,9,8])
dates=pd.date_range("20240501",periods=10)
dates

df=pd.DataFrame(np.random.randn(10,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2024-05-01 -0.072663  0.146708 -0.754456 -1.766164
# 2024-05-02 -0.361061 -1.616915 -0.690282  1.255264
# 2024-05-03  0.492789  0.657576 -0.969594  0.872611
# 2024-05-04 -0.138082  1.586582  1.627948  0.203504
# 2024-05-05  0.966813  0.822899 -0.472636 -1.224267
# 2024-05-06 -1.868238 -0.956237 -1.234173  1.612371
# 2024-05-07  1.260056 -0.286271  0.160383 -0.034173
# 2024-05-08 -1.580347  0.504541  0.548171 -1.398408
# 2024-05-09 -0.679632  0.467943 -1.069041  1.903747
# 2024-05-10 -0.054269 -0.048112  0.029978 -0.411368

# %%
df2=pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20240501"),
        "C": pd.Series(1,index=list(range(4)),dtype="float32"),
        "D": np.array([3]*4,dtype="int32"),
        "E": pd.Categorical(["test","train","test","train"]),
        "F":"foo",
    }
)
# print(df2)
df2.dtypes
df2.head(3)
# df2.tail()
df2.index
df2.columns
df2.to_numpy()
aa=df.to_numpy()
df.describe()
df.sort_index(axis=1,ascending=False)
df.sort_values(by="D")
# Out:
#                    A         B         C         D
# 2024-05-01 -0.072663  0.146708 -0.754456 -1.766164
# 2024-05-08 -1.580347  0.504541  0.548171 -1.398408
# 2024-05-05  0.966813  0.822899 -0.472636 -1.224267
# 2024-05-10 -0.054269 -0.048112  0.029978 -0.411368
# 2024-05-07  1.260056 -0.286271  0.160383 -0.034173
# 2024-05-04 -0.138082  1.586582  1.627948  0.203504
# 2024-05-03  0.492789  0.657576 -0.969594  0.872611
# 2024-05-02 -0.361061 -1.616915 -0.690282  1.255264
# 2024-05-06 -1.868238 -0.956237 -1.234173  1.612371
# 2024-05-09 -0.679632  0.467943 -1.069041  1.903747

# %%
# df[0:3]
# df.loc[dates[0]]
df.loc[dates[0],"A"]
df[df["A"]>0]
df3=df.copy()
df["E"]=["ss","sh"]*5
# df[df["A"].isin([0.354107,0.767608])]
df
# s1=pd.Series([1,2,3,4,5,6],index=pd.date_range("20250501",periods=6))
# s1
import os
df_bks=pd.read_excel(os.listdir(".")[1])
df_bks=df_bks.dropna(subset=["Name ","Datum"])
df_bks.loc["Name "]
# df_bks.drop([0,1],axis=0)

# str1="RM_stacked"
# for nm in df_bks["Name "]:
#     if(not(str1 in nm)):
#         df_bks=df_bks.drop(df_bks["Name "])


# df_bks_filter = df_bks[df_bks['Name '].str.contains('RM_stacked')]

# str1="jjjsdfldslf"
# str2="dfld"
# a= str2 in str1
# a

# df_bks
# df_bks.columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Gaming\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Gaming\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Gaming\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:155, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Name '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
